# %% [markdown]
# ## Sort
# ## Copyright: Jagadeesh Vasudevamurthy
# ## filename:Sort.ipynb

# %%
import sys # For getting Python Version
import random
import time

# %% [markdown]
# # Sort Class

# %%
class Sort():
    def __init__(self, data:'list'):
        self._data = data
        
    def qsort(self):
        self._qSortR(0, len(self._data) - 1)

    def _qSortR(self, start, end):
        if start < end:
            pivot_index = self._qpartition(start, end)
            self._qSortR(start, pivot_index - 1)
            self._qSortR(pivot_index + 1, end)

    def _swap(self, indexA, indexB):
        self._data[indexA], self._data[indexB] = self._data[indexB], self._data[indexA]

    def _compare(self, a, b):
        return (a > b) - (a < b)

    def _qpartition(self, start, end):
        pivot = self._data[start]
        pivot_index = start
        i, j = start + 1, end
        
        while True:
            while i <= j and self._compare(self._data[i][0], pivot[0]) <= 0:
                i += 1
            while i <= j and self._compare(self._data[j][0], pivot[0]) > 0:
                j -= 1
            if i <= j:
                self._swap(i, j)
            else:
                break

        self._swap(pivot_index, j)
        return j

    def mergesort(self):
        self._mergeSortR(0, len(self._data))

    def _mergeSortR(self, start, end):
        mid = (end - start) // 2 + start
        if end - start > 1:
            self._mergeSortR(start, mid)
            self._mergeSortR(mid, end)
            self._merge(start, mid, end)

    def _merge(self, start, mid, end):
        i, j, k = start, mid, 0
        temp = [0] * (end - start)

        while i < mid and j < end:
            if self._compare(self._data[i][0], self._data[j][0]) <= 0:
                temp[k] = self._data[i]
                i += 1
            else:
                temp[k] = self._data[j]
                j += 1
            k += 1

        while i < mid:
            temp[k] = self._data[i]
            i += 1
            k += 1

        while j < end:
            temp[k] = self._data[j]
            j += 1
            k += 1

        for index in range(k):
            self._data[start + index] = temp[index]

# %% [markdown]
# # Sort test class
# # NOTHING CAN BE CHANGED BELOW

# %%
class Sort():
    def __init__(self, data:'list'):
        self._data = data
        self.comparisons = 0
        self.swaps = 0
        self.recursions = 0
        self.show = True
        
    def qsort(self):
        self.comparisons = 0
        self.swaps = 0
        self.recursions = 0
        self._qSortR(0, len(self._data) - 1)
        print(f"Quick Sort - Comparisons: {self.comparisons}, Swaps: {self.swaps}, Recursions: {self.recursions}")

    def mergesort(self):
        self.comparisons = 0
        self.swaps = 0
        self.recursions = 0
        self._mergeSortR(0, len(self._data))
        print(f"Merge Sort - Comparisons: {self.comparisons}, Swaps: {self.swaps}, Recursions: {self.recursions}")

    def _qSortR(self, low, high):
        self.recursions += 1
        if self.show:
            print(f"Quick Sort: Sorting from index {low} to {high}")
            print(self._data)
        if low < high:
            pivot_index = self._qPartition(low, high)
            self._qSortR(low, pivot_index - 1)
            self._qSortR(pivot_index + 1, high)

    def _qPartition(self, low, high):
        pivot = self._data[low]
        pivot_index = low
        i, j = low + 1, high
        while True:
            while i <= j and (self._data[i][0] < self._data[pivot_index][0] or (self._data[i][0] == self._data[pivot_index][0])):
                self.comparisons += 1
                i += 1
            while i <= j and self._data[j][0] > self._data[pivot_index][0]:
                self.comparisons += 1
                j -= 1
            if i <= j:
                self._data[i], self._data[j] = self._data[j], self._data[i]
                self.swaps += 1
            else:
                break
        self._data[pivot_index], self._data[j] = self._data[j], self._data[pivot_index]
        self.swaps += 1
        if self.show:
            print(f"Partitioned at index {j} with pivot {pivot}")
            print(self._data)
        return j

    def _mergeSortR(self, low, high):
        self.recursions += 1
        if self.show:
            print(f"Merge Sort: Sorting from index {low} to {high}")
            print(self._data)
        mid = (high - low) // 2 + low
        if high - low > 1:
            self._mergeSortR(low, mid)
            self._mergeSortR(mid, high)
            self._merge(low, mid, high)

    def _merge(self, low, mid, high):
        if self.show:
            print(f"Merging from index {low} to {high}")
            print(self._data)
        i, j, k = low, mid, 0
        temp = [0] * (high - low)
        while i < mid and j < high:
            self.comparisons += 1
            if (self._data[i][0] < self._data[j][0]) or (self._data[i][0] == self._data[j][0] and self._data[i][1] < self._data[j][1]):
                temp[k] = self._data[i]
                i += 1
            else:
                temp[k] = self._data[j]
                j += 1
            k += 1
        while i < mid:
            temp[k] = self._data[i]
            i += 1
            k += 1
        while j < high:
            temp[k] = self._data[j]
            j += 1
            k += 1
        for index in range(k):
            self._data[low + index] = temp[index]
            self.swaps += 1
        if self.show:
            print(f"Merged section from index {low} to {high}")
            print(self._data)

# %% [markdown]
# # main

# %%
############################################################
# start up
###########################################################
if (__name__  == '__main__'):
    main()
# Out:
# Basic Sort test starts
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
# ------ Sorting Example  1  ------------
# Original Data: []
# golden_sorted_data []
# Quick Sort: Sorting from index 0 to -1
# []
# Quick Sort - Comparisons: 0, Swaps: 0, Recursions: 1
# Quick sorted: []
# Merge Sort: Sorting from index 0 to 0
# []
# Merge Sort - Comparisons: 0, Swaps: 0, Recursions: 1
# Merge sorted: []
# ------ Sorting Example  2  ------------
# Original Data: [(0, 0)]
# golden_sorted_data [(0, 0)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 0)]
# Quick Sort - Comparisons: 0, Swaps: 0, Recursions: 1
# Quick sorted: [(0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0)]
# Merge Sort - Comparisons: 0, Swaps: 0, Recursions: 1
# Merge sorted: [(0, 0)]
# ------ Sorting Example  3  ------------
# Original Data: [(0, 0), (1, 1)]
# golden_sorted_data [(0, 0), (1, 1)]
# Quick Sort: Sorting from index 0 to 1
# [(0, 0), (1, 1)]
# Partitioned at index 0 with pivot (0, 0)
# [(0, 0), (1, 1)]
# Quick Sort: Sorting from index 0 to -1
# [(0, 0), (1, 1)]
# Quick Sort: Sorting from index 1 to 1
# [(0, 0), (1, 1)]
# Quick Sort - Comparisons: 1, Swaps: 1, Recursions: 3
# Quick sorted: [(0, 0), (1, 1)]
# Merge Sort: Sorting from index 0 to 2
# [(0, 0), (1, 1)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0), (1, 1)]
# Merge Sort: Sorting from index 1 to 2
# [(0, 0), (1, 1)]
# Merging from index 0 to 2
# [(0, 0), (1, 1)]
# Merged section from index 0 to 2
# [(0, 0), (1, 1)]
# Merge Sort - Comparisons: 1, Swaps: 2, Recursions: 3
# Merge sorted: [(0, 0), (1, 1)]
# ------ Sorting Example  4  ------------
# Original Data: [(0, 0), (0, 1), (1, 2)]
# golden_sorted_data [(0, 0), (0, 1), (1, 2)]
# Quick Sort: Sorting from index 0 to 2
# [(0, 0), (0, 1), (1, 2)]
# Partitioned at index 1 with pivot (0, 0)
# [(0, 1), (0, 0), (1, 2)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 0), (1, 2)]
# Quick Sort: Sorting from index 2 to 2
# [(0, 1), (0, 0), (1, 2)]
# Quick Sort - Comparisons: 2, Swaps: 1, Recursions: 3
# Quick sorted: [(0, 1), (0, 0), (1, 2)]
# Merge Sort: Sorting from index 0 to 3
# [(0, 0), (0, 1), (1, 2)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0), (0, 1), (1, 2)]
# Merge Sort: Sorting from index 1 to 3
# [(0, 0), (0, 1), (1, 2)]
# Merge Sort: Sorting from index 1 to 2
# [(0, 0), (0, 1), (1, 2)]
# Merge Sort: Sorting from index 2 to 3
# [(0, 0), (0, 1), (1, 2)]
# Merging from index 1 to 3
# [(0, 0), (0, 1), (1, 2)]
# Merged section from index 1 to 3
# [(0, 0), (0, 1), (1, 2)]
# Merging from index 0 to 3
# [(0, 0), (0, 1), (1, 2)]
# Merged section from index 0 to 3
# [(0, 0), (0, 1), (1, 2)]
# Merge Sort - Comparisons: 2, Swaps: 5, Recursions: 5
# Merge sorted: [(0, 0), (0, 1), (1, 2)]
# ------ Sorting Example  5  ------------
# Original Data: [(0, 0), (0, 1), (1, 2), (3, 3)]
# golden_sorted_data [(0, 0), (0, 1), (1, 2), (3, 3)]
# Quick Sort: Sorting from index 0 to 3
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Partitioned at index 1 with pivot (0, 0)
# [(0, 1), (0, 0), (1, 2), (3, 3)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 0), (1, 2), (3, 3)]
# Quick Sort: Sorting from index 2 to 3
# [(0, 1), (0, 0), (1, 2), (3, 3)]
# Partitioned at index 2 with pivot (1, 2)
# [(0, 1), (0, 0), (1, 2), (3, 3)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 1), (0, 0), (1, 2), (3, 3)]
# Quick Sort: Sorting from index 3 to 3
# [(0, 1), (0, 0), (1, 2), (3, 3)]
# Quick Sort - Comparisons: 4, Swaps: 2, Recursions: 5
# Quick sorted: [(0, 1), (0, 0), (1, 2), (3, 3)]
# Merge Sort: Sorting from index 0 to 4
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merge Sort: Sorting from index 0 to 2
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merge Sort: Sorting from index 1 to 2
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merging from index 0 to 2
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merged section from index 0 to 2
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merge Sort: Sorting from index 2 to 4
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merge Sort: Sorting from index 2 to 3
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merge Sort: Sorting from index 3 to 4
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merging from index 2 to 4
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merged section from index 2 to 4
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merging from index 0 to 4
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merged section from index 0 to 4
# [(0, 0), (0, 1), (1, 2), (3, 3)]
# Merge Sort - Comparisons: 4, Swaps: 8, Recursions: 7
# Merge sorted: [(0, 0), (0, 1), (1, 2), (3, 3)]
# ------ Sorting Example  6  ------------
# Original Data: [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# golden_sorted_data [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Quick Sort: Sorting from index 0 to 4
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Partitioned at index 2 with pivot (0, 0)
# [(0, 2), (0, 1), (0, 0), (3, 3), (3, 4)]
# Quick Sort: Sorting from index 0 to 1
# [(0, 2), (0, 1), (0, 0), (3, 3), (3, 4)]
# Partitioned at index 1 with pivot (0, 2)
# [(0, 1), (0, 2), (0, 0), (3, 3), (3, 4)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 2), (0, 0), (3, 3), (3, 4)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 1), (0, 2), (0, 0), (3, 3), (3, 4)]
# Quick Sort: Sorting from index 3 to 4
# [(0, 1), (0, 2), (0, 0), (3, 3), (3, 4)]
# Partitioned at index 4 with pivot (3, 3)
# [(0, 1), (0, 2), (0, 0), (3, 4), (3, 3)]
# Quick Sort: Sorting from index 3 to 3
# [(0, 1), (0, 2), (0, 0), (3, 4), (3, 3)]
# Quick Sort: Sorting from index 5 to 4
# [(0, 1), (0, 2), (0, 0), (3, 4), (3, 3)]
# Quick Sort - Comparisons: 6, Swaps: 3, Recursions: 7
# Quick sorted: [(0, 1), (0, 2), (0, 0), (3, 4), (3, 3)]
# Merge Sort: Sorting from index 0 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merge Sort: Sorting from index 0 to 2
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merge Sort: Sorting from index 1 to 2
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merging from index 0 to 2
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merged section from index 0 to 2
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merge Sort: Sorting from index 2 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merge Sort: Sorting from index 2 to 3
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merge Sort: Sorting from index 3 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merge Sort: Sorting from index 3 to 4
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merge Sort: Sorting from index 4 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merging from index 3 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merged section from index 3 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merging from index 2 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merged section from index 2 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merging from index 0 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merged section from index 0 to 5
# [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# Merge Sort - Comparisons: 5, Swaps: 12, Recursions: 9
# Merge sorted: [(0, 0), (0, 1), (0, 2), (3, 3), (3, 4)]
# ------ Sorting Example  7  ------------
# Original Data: [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# golden_sorted_data [(0, 0), (0, 1), (1, 2), (2, 4), (2, 5), (3, 3)]
# Quick Sort: Sorting from index 0 to 5
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Partitioned at index 1 with pivot (0, 0)
# [(0, 1), (0, 0), (1, 2), (3, 3), (2, 4), (2, 5)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 0), (1, 2), (3, 3), (2, 4), (2, 5)]
# Quick Sort: Sorting from index 2 to 5
# [(0, 1), (0, 0), (1, 2), (3, 3), (2, 4), (2, 5)]
# Partitioned at index 2 with pivot (1, 2)
# [(0, 1), (0, 0), (1, 2), (3, 3), (2, 4), (2, 5)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 1), (0, 0), (1, 2), (3, 3), (2, 4), (2, 5)]
# Quick Sort: Sorting from index 3 to 5
# [(0, 1), (0, 0), (1, 2), (3, 3), (2, 4), (2, 5)]
# Partitioned at index 5 with pivot (3, 3)
# [(0, 1), (0, 0), (1, 2), (2, 5), (2, 4), (3, 3)]
# Quick Sort: Sorting from index 3 to 4
# [(0, 1), (0, 0), (1, 2), (2, 5), (2, 4), (3, 3)]
# Partitioned at index 4 with pivot (2, 5)
# [(0, 1), (0, 0), (1, 2), (2, 4), (2, 5), (3, 3)]
# Quick Sort: Sorting from index 3 to 3
# [(0, 1), (0, 0), (1, 2), (2, 4), (2, 5), (3, 3)]
# Quick Sort: Sorting from index 5 to 4
# [(0, 1), (0, 0), (1, 2), (2, 4), (2, 5), (3, 3)]
# Quick Sort: Sorting from index 6 to 5
# [(0, 1), (0, 0), (1, 2), (2, 4), (2, 5), (3, 3)]
# Quick Sort - Comparisons: 11, Swaps: 4, Recursions: 9
# Quick sorted: [(0, 1), (0, 0), (1, 2), (2, 4), (2, 5), (3, 3)]
# Merge Sort: Sorting from index 0 to 6
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 0 to 3
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 1 to 3
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 1 to 2
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 2 to 3
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merging from index 1 to 3
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merged section from index 1 to 3
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merging from index 0 to 3
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merged section from index 0 to 3
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 3 to 6
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 3 to 4
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 4 to 6
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 4 to 5
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merge Sort: Sorting from index 5 to 6
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merging from index 4 to 6
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merged section from index 4 to 6
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merging from index 3 to 6
# [(0, 0), (0, 1), (1, 2), (3, 3), (2, 4), (2, 5)]
# Merged section from index 3 to 6
# [(0, 0), (0, 1), (1, 2), (2, 4), (2, 5), (3, 3)]
# Merging from index 0 to 6
# [(0, 0), (0, 1), (1, 2), (2, 4), (2, 5), (3, 3)]
# Merged section from index 0 to 6
# [(0, 0), (0, 1), (1, 2), (2, 4), (2, 5), (3, 3)]
# Merge Sort - Comparisons: 8, Swaps: 16, Recursions: 11
# Merge sorted: [(0, 0), (0, 1), (1, 2), (2, 4), (2, 5), (3, 3)]
# ------ Sorting Example  8  ------------
# Original Data: [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# golden_sorted_data [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 0 to 6
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Partitioned at index 0 with pivot (0, 0)
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 0 to -1
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 1 to 6
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Partitioned at index 3 with pivot (1, 1)
# [(0, 0), (1, 4), (1, 2), (1, 1), (2, 3), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 1 to 2
# [(0, 0), (1, 4), (1, 2), (1, 1), (2, 3), (4, 5), (5, 6)]
# Partitioned at index 2 with pivot (1, 4)
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 1 to 1
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 3 to 2
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 4 to 6
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Partitioned at index 4 with pivot (2, 3)
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 4 to 3
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 5 to 6
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Partitioned at index 5 with pivot (4, 5)
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 5 to 4
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Quick Sort: Sorting from index 6 to 6
# [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Quick Sort - Comparisons: 15, Swaps: 6, Recursions: 11
# Quick sorted: [(0, 0), (1, 2), (1, 4), (1, 1), (2, 3), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 0 to 7
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 0 to 3
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 1 to 3
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 1 to 2
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 2 to 3
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merging from index 1 to 3
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merged section from index 1 to 3
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merging from index 0 to 3
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merged section from index 0 to 3
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 3 to 7
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 3 to 5
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 3 to 4
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 4 to 5
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merging from index 3 to 5
# [(0, 0), (1, 1), (1, 2), (2, 3), (1, 4), (4, 5), (5, 6)]
# Merged section from index 3 to 5
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 5 to 7
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 5 to 6
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merge Sort: Sorting from index 6 to 7
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merging from index 5 to 7
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merged section from index 5 to 7
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merging from index 3 to 7
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merged section from index 3 to 7
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merging from index 0 to 7
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merged section from index 0 to 7
# [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# Merge Sort - Comparisons: 9, Swaps: 20, Recursions: 13
# Merge sorted: [(0, 0), (1, 1), (1, 2), (1, 4), (2, 3), (4, 5), (5, 6)]
# ------ Sorting Example  9  ------------
# Original Data: [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# golden_sorted_data [(0, 0), (0, 1), (0, 2), (1, 3), (2, 6), (4, 4), (4, 5), (5, 7)]
# Quick Sort: Sorting from index 0 to 7
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Partitioned at index 2 with pivot (0, 0)
# [(0, 2), (0, 1), (0, 0), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Quick Sort: Sorting from index 0 to 1
# [(0, 2), (0, 1), (0, 0), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Partitioned at index 1 with pivot (0, 2)
# [(0, 1), (0, 2), (0, 0), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 2), (0, 0), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 1), (0, 2), (0, 0), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Quick Sort: Sorting from index 3 to 7
# [(0, 1), (0, 2), (0, 0), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Partitioned at index 3 with pivot (1, 3)
# [(0, 1), (0, 2), (0, 0), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Quick Sort: Sorting from index 3 to 2
# [(0, 1), (0, 2), (0, 0), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Quick Sort: Sorting from index 4 to 7
# [(0, 1), (0, 2), (0, 0), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Partitioned at index 6 with pivot (4, 4)
# [(0, 1), (0, 2), (0, 0), (1, 3), (2, 6), (4, 5), (4, 4), (5, 7)]
# Quick Sort: Sorting from index 4 to 5
# [(0, 1), (0, 2), (0, 0), (1, 3), (2, 6), (4, 5), (4, 4), (5, 7)]
# Partitioned at index 4 with pivot (2, 6)
# [(0, 1), (0, 2), (0, 0), (1, 3), (2, 6), (4, 5), (4, 4), (5, 7)]
# Quick Sort: Sorting from index 4 to 3
# [(0, 1), (0, 2), (0, 0), (1, 3), (2, 6), (4, 5), (4, 4), (5, 7)]
# Quick Sort: Sorting from index 5 to 5
# [(0, 1), (0, 2), (0, 0), (1, 3), (2, 6), (4, 5), (4, 4), (5, 7)]
# Quick Sort: Sorting from index 7 to 7
# [(0, 1), (0, 2), (0, 0), (1, 3), (2, 6), (4, 5), (4, 4), (5, 7)]
# Quick Sort - Comparisons: 16, Swaps: 5, Recursions: 11
# Quick sorted: [(0, 1), (0, 2), (0, 0), (1, 3), (2, 6), (4, 5), (4, 4), (5, 7)]
# Merge Sort: Sorting from index 0 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 0 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 0 to 2
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 1 to 2
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merging from index 0 to 2
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merged section from index 0 to 2
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 2 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 2 to 3
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 3 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merging from index 2 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merged section from index 2 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merging from index 0 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merged section from index 0 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 4 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 4 to 6
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 4 to 5
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 5 to 6
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merging from index 4 to 6
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merged section from index 4 to 6
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 6 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 6 to 7
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merge Sort: Sorting from index 7 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merging from index 6 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merged section from index 6 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merging from index 4 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (4, 4), (4, 5), (2, 6), (5, 7)]
# Merged section from index 4 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (2, 6), (4, 4), (4, 5), (5, 7)]
# Merging from index 0 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (2, 6), (4, 4), (4, 5), (5, 7)]
# Merged section from index 0 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (2, 6), (4, 4), (4, 5), (5, 7)]
# Merge Sort - Comparisons: 13, Swaps: 24, Recursions: 15
# Merge sorted: [(0, 0), (0, 1), (0, 2), (1, 3), (2, 6), (4, 4), (4, 5), (5, 7)]
# ------ Sorting Example  10  ------------
# Original Data: [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# golden_sorted_data [(0, 0), (0, 1), (0, 2), (0, 5), (0, 6), (1, 3), (1, 4), (2, 8), (7, 7)]
# Quick Sort: Sorting from index 0 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Partitioned at index 4 with pivot (0, 0)
# [(0, 5), (0, 1), (0, 2), (0, 6), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 0 to 3
# [(0, 5), (0, 1), (0, 2), (0, 6), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Partitioned at index 3 with pivot (0, 5)
# [(0, 6), (0, 1), (0, 2), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 0 to 2
# [(0, 6), (0, 1), (0, 2), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Partitioned at index 2 with pivot (0, 6)
# [(0, 2), (0, 1), (0, 6), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 0 to 1
# [(0, 2), (0, 1), (0, 6), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Partitioned at index 1 with pivot (0, 2)
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 3 to 2
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 4 to 3
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 5 to 8
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 4), (1, 3), (7, 7), (2, 8)]
# Partitioned at index 6 with pivot (1, 4)
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 3), (1, 4), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 5 to 5
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 3), (1, 4), (7, 7), (2, 8)]
# Quick Sort: Sorting from index 7 to 8
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 3), (1, 4), (7, 7), (2, 8)]
# Partitioned at index 8 with pivot (7, 7)
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 3), (1, 4), (2, 8), (7, 7)]
# Quick Sort: Sorting from index 7 to 7
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 3), (1, 4), (2, 8), (7, 7)]
# Quick Sort: Sorting from index 9 to 8
# [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 3), (1, 4), (2, 8), (7, 7)]
# Quick Sort - Comparisons: 18, Swaps: 8, Recursions: 13
# Quick sorted: [(0, 1), (0, 2), (0, 6), (0, 5), (0, 0), (1, 3), (1, 4), (2, 8), (7, 7)]
# Merge Sort: Sorting from index 0 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 0 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 0 to 2
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 1 to 2
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merging from index 0 to 2
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merged section from index 0 to 2
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 2 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 2 to 3
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 3 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merging from index 2 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merged section from index 2 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merging from index 0 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merged section from index 0 to 4
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 4 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 4 to 6
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 4 to 5
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 5 to 6
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merging from index 4 to 6
# [(0, 0), (0, 1), (0, 2), (1, 3), (1, 4), (0, 5), (0, 6), (7, 7), (2, 8)]
# Merged section from index 4 to 6
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 6 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 6 to 7
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 7 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 7 to 8
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (7, 7), (2, 8)]
# Merge Sort: Sorting from index 8 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (7, 7), (2, 8)]
# Merging from index 7 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (7, 7), (2, 8)]
# Merged section from index 7 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (2, 8), (7, 7)]
# Merging from index 6 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (2, 8), (7, 7)]
# Merged section from index 6 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (2, 8), (7, 7)]
# Merging from index 4 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (1, 4), (0, 6), (2, 8), (7, 7)]
# Merged section from index 4 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (0, 6), (1, 4), (2, 8), (7, 7)]
# Merging from index 0 to 9
# [(0, 0), (0, 1), (0, 2), (1, 3), (0, 5), (0, 6), (1, 4), (2, 8), (7, 7)]
# Merged section from index 0 to 9
# [(0, 0), (0, 1), (0, 2), (0, 5), (0, 6), (1, 3), (1, 4), (2, 8), (7, 7)]
# Merge Sort - Comparisons: 16, Swaps: 29, Recursions: 17
# Merge sorted: [(0, 0), (0, 1), (0, 2), (0, 5), (0, 6), (1, 3), (1, 4), (2, 8), (7, 7)]
# ------ Sorting Example  11  ------------
# Original Data: []
# golden_sorted_data []
# Quick Sort: Sorting from index 0 to -1
# []
# Quick Sort - Comparisons: 0, Swaps: 0, Recursions: 1
# Quick sorted: []
# Merge Sort: Sorting from index 0 to 0
# []
# Merge Sort - Comparisons: 0, Swaps: 0, Recursions: 1
# Merge sorted: []
# ------ Sorting Example  12  ------------
# Original Data: [(0, 0)]
# golden_sorted_data [(0, 0)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 0)]
# Quick Sort - Comparisons: 0, Swaps: 0, Recursions: 1
# Quick sorted: [(0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(0, 0)]
# Merge Sort - Comparisons: 0, Swaps: 0, Recursions: 1
# Merge sorted: [(0, 0)]
# ------ Sorting Example  13  ------------
# Original Data: [(1, 1), (0, 0)]
# golden_sorted_data [(0, 0), (1, 1)]
# Quick Sort: Sorting from index 0 to 1
# [(1, 1), (0, 0)]
# Partitioned at index 1 with pivot (1, 1)
# [(0, 0), (1, 1)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 0), (1, 1)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 0), (1, 1)]
# Quick Sort - Comparisons: 1, Swaps: 1, Recursions: 3
# Quick sorted: [(0, 0), (1, 1)]
# Merge Sort: Sorting from index 0 to 2
# [(1, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(1, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 2
# [(1, 1), (0, 0)]
# Merging from index 0 to 2
# [(1, 1), (0, 0)]
# Merged section from index 0 to 2
# [(0, 0), (1, 1)]
# Merge Sort - Comparisons: 1, Swaps: 2, Recursions: 3
# Merge sorted: [(0, 0), (1, 1)]
# ------ Sorting Example  14  ------------
# Original Data: [(2, 2), (0, 1), (0, 0)]
# golden_sorted_data [(0, 0), (0, 1), (2, 2)]
# Quick Sort: Sorting from index 0 to 2
# [(2, 2), (0, 1), (0, 0)]
# Partitioned at index 2 with pivot (2, 2)
# [(0, 0), (0, 1), (2, 2)]
# Quick Sort: Sorting from index 0 to 1
# [(0, 0), (0, 1), (2, 2)]
# Partitioned at index 1 with pivot (0, 0)
# [(0, 1), (0, 0), (2, 2)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 0), (2, 2)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 1), (0, 0), (2, 2)]
# Quick Sort: Sorting from index 3 to 2
# [(0, 1), (0, 0), (2, 2)]
# Quick Sort - Comparisons: 3, Swaps: 2, Recursions: 5
# Quick sorted: [(0, 1), (0, 0), (2, 2)]
# Merge Sort: Sorting from index 0 to 3
# [(2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 3
# [(2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 2
# [(2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 3
# [(2, 2), (0, 1), (0, 0)]
# Merging from index 1 to 3
# [(2, 2), (0, 1), (0, 0)]
# Merged section from index 1 to 3
# [(2, 2), (0, 0), (0, 1)]
# Merging from index 0 to 3
# [(2, 2), (0, 0), (0, 1)]
# Merged section from index 0 to 3
# [(0, 0), (0, 1), (2, 2)]
# Merge Sort - Comparisons: 3, Swaps: 5, Recursions: 5
# Merge sorted: [(0, 0), (0, 1), (2, 2)]
# ------ Sorting Example  15  ------------
# Original Data: [(2, 3), (2, 2), (0, 1), (0, 0)]
# golden_sorted_data [(0, 0), (0, 1), (2, 2), (2, 3)]
# Quick Sort: Sorting from index 0 to 3
# [(2, 3), (2, 2), (0, 1), (0, 0)]
# Partitioned at index 3 with pivot (2, 3)
# [(0, 0), (2, 2), (0, 1), (2, 3)]
# Quick Sort: Sorting from index 0 to 2
# [(0, 0), (2, 2), (0, 1), (2, 3)]
# Partitioned at index 1 with pivot (0, 0)
# [(0, 1), (0, 0), (2, 2), (2, 3)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 0), (2, 2), (2, 3)]
# Quick Sort: Sorting from index 2 to 2
# [(0, 1), (0, 0), (2, 2), (2, 3)]
# Quick Sort: Sorting from index 4 to 3
# [(0, 1), (0, 0), (2, 2), (2, 3)]
# Quick Sort - Comparisons: 5, Swaps: 3, Recursions: 5
# Quick sorted: [(0, 1), (0, 0), (2, 2), (2, 3)]
# Merge Sort: Sorting from index 0 to 4
# [(2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 2
# [(2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 2
# [(2, 3), (2, 2), (0, 1), (0, 0)]
# Merging from index 0 to 2
# [(2, 3), (2, 2), (0, 1), (0, 0)]
# Merged section from index 0 to 2
# [(2, 2), (2, 3), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 4
# [(2, 2), (2, 3), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 3
# [(2, 2), (2, 3), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 4
# [(2, 2), (2, 3), (0, 1), (0, 0)]
# Merging from index 2 to 4
# [(2, 2), (2, 3), (0, 1), (0, 0)]
# Merged section from index 2 to 4
# [(2, 2), (2, 3), (0, 0), (0, 1)]
# Merging from index 0 to 4
# [(2, 2), (2, 3), (0, 0), (0, 1)]
# Merged section from index 0 to 4
# [(0, 0), (0, 1), (2, 2), (2, 3)]
# Merge Sort - Comparisons: 4, Swaps: 8, Recursions: 7
# Merge sorted: [(0, 0), (0, 1), (2, 2), (2, 3)]
# ------ Sorting Example  16  ------------
# Original Data: [(3, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# golden_sorted_data [(0, 0), (0, 3), (1, 1), (2, 2), (3, 4)]
# Quick Sort: Sorting from index 0 to 4
# [(3, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Partitioned at index 4 with pivot (3, 4)
# [(0, 0), (0, 3), (2, 2), (1, 1), (3, 4)]
# Quick Sort: Sorting from index 0 to 3
# [(0, 0), (0, 3), (2, 2), (1, 1), (3, 4)]
# Partitioned at index 1 with pivot (0, 0)
# [(0, 3), (0, 0), (2, 2), (1, 1), (3, 4)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 3), (0, 0), (2, 2), (1, 1), (3, 4)]
# Quick Sort: Sorting from index 2 to 3
# [(0, 3), (0, 0), (2, 2), (1, 1), (3, 4)]
# Partitioned at index 3 with pivot (2, 2)
# [(0, 3), (0, 0), (1, 1), (2, 2), (3, 4)]
# Quick Sort: Sorting from index 2 to 2
# [(0, 3), (0, 0), (1, 1), (2, 2), (3, 4)]
# Quick Sort: Sorting from index 4 to 3
# [(0, 3), (0, 0), (1, 1), (2, 2), (3, 4)]
# Quick Sort: Sorting from index 5 to 4
# [(0, 3), (0, 0), (1, 1), (2, 2), (3, 4)]
# Quick Sort - Comparisons: 8, Swaps: 3, Recursions: 7
# Quick sorted: [(0, 3), (0, 0), (1, 1), (2, 2), (3, 4)]
# Merge Sort: Sorting from index 0 to 5
# [(3, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 2
# [(3, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(3, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 2
# [(3, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merging from index 0 to 2
# [(3, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merged section from index 0 to 2
# [(0, 3), (3, 4), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 5
# [(0, 3), (3, 4), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 3
# [(0, 3), (3, 4), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 5
# [(0, 3), (3, 4), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 4
# [(0, 3), (3, 4), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 5
# [(0, 3), (3, 4), (2, 2), (1, 1), (0, 0)]
# Merging from index 3 to 5
# [(0, 3), (3, 4), (2, 2), (1, 1), (0, 0)]
# Merged section from index 3 to 5
# [(0, 3), (3, 4), (2, 2), (0, 0), (1, 1)]
# Merging from index 2 to 5
# [(0, 3), (3, 4), (2, 2), (0, 0), (1, 1)]
# Merged section from index 2 to 5
# [(0, 3), (3, 4), (0, 0), (1, 1), (2, 2)]
# Merging from index 0 to 5
# [(0, 3), (3, 4), (0, 0), (1, 1), (2, 2)]
# Merged section from index 0 to 5
# [(0, 0), (0, 3), (1, 1), (2, 2), (3, 4)]
# Merge Sort - Comparisons: 8, Swaps: 12, Recursions: 9
# Merge sorted: [(0, 0), (0, 3), (1, 1), (2, 2), (3, 4)]
# ------ Sorting Example  17  ------------
# Original Data: [(4, 5), (2, 4), (0, 3), (0, 2), (1, 1), (0, 0)]
# golden_sorted_data [(0, 0), (0, 2), (0, 3), (1, 1), (2, 4), (4, 5)]
# Quick Sort: Sorting from index 0 to 5
# [(4, 5), (2, 4), (0, 3), (0, 2), (1, 1), (0, 0)]
# Partitioned at index 5 with pivot (4, 5)
# [(0, 0), (2, 4), (0, 3), (0, 2), (1, 1), (4, 5)]
# Quick Sort: Sorting from index 0 to 4
# [(0, 0), (2, 4), (0, 3), (0, 2), (1, 1), (4, 5)]
# Partitioned at index 2 with pivot (0, 0)
# [(0, 3), (0, 2), (0, 0), (2, 4), (1, 1), (4, 5)]
# Quick Sort: Sorting from index 0 to 1
# [(0, 3), (0, 2), (0, 0), (2, 4), (1, 1), (4, 5)]
# Partitioned at index 1 with pivot (0, 3)
# [(0, 2), (0, 3), (0, 0), (2, 4), (1, 1), (4, 5)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 2), (0, 3), (0, 0), (2, 4), (1, 1), (4, 5)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 2), (0, 3), (0, 0), (2, 4), (1, 1), (4, 5)]
# Quick Sort: Sorting from index 3 to 4
# [(0, 2), (0, 3), (0, 0), (2, 4), (1, 1), (4, 5)]
# Partitioned at index 4 with pivot (2, 4)
# [(0, 2), (0, 3), (0, 0), (1, 1), (2, 4), (4, 5)]
# Quick Sort: Sorting from index 3 to 3
# [(0, 2), (0, 3), (0, 0), (1, 1), (2, 4), (4, 5)]
# Quick Sort: Sorting from index 5 to 4
# [(0, 2), (0, 3), (0, 0), (1, 1), (2, 4), (4, 5)]
# Quick Sort: Sorting from index 6 to 5
# [(0, 2), (0, 3), (0, 0), (1, 1), (2, 4), (4, 5)]
# Quick Sort - Comparisons: 11, Swaps: 5, Recursions: 9
# Quick sorted: [(0, 2), (0, 3), (0, 0), (1, 1), (2, 4), (4, 5)]
# Merge Sort: Sorting from index 0 to 6
# [(4, 5), (2, 4), (0, 3), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 3
# [(4, 5), (2, 4), (0, 3), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(4, 5), (2, 4), (0, 3), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 3
# [(4, 5), (2, 4), (0, 3), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 2
# [(4, 5), (2, 4), (0, 3), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 3
# [(4, 5), (2, 4), (0, 3), (0, 2), (1, 1), (0, 0)]
# Merging from index 1 to 3
# [(4, 5), (2, 4), (0, 3), (0, 2), (1, 1), (0, 0)]
# Merged section from index 1 to 3
# [(4, 5), (0, 3), (2, 4), (0, 2), (1, 1), (0, 0)]
# Merging from index 0 to 3
# [(4, 5), (0, 3), (2, 4), (0, 2), (1, 1), (0, 0)]
# Merged section from index 0 to 3
# [(0, 3), (2, 4), (4, 5), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 6
# [(0, 3), (2, 4), (4, 5), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 4
# [(0, 3), (2, 4), (4, 5), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 6
# [(0, 3), (2, 4), (4, 5), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 5
# [(0, 3), (2, 4), (4, 5), (0, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 5 to 6
# [(0, 3), (2, 4), (4, 5), (0, 2), (1, 1), (0, 0)]
# Merging from index 4 to 6
# [(0, 3), (2, 4), (4, 5), (0, 2), (1, 1), (0, 0)]
# Merged section from index 4 to 6
# [(0, 3), (2, 4), (4, 5), (0, 2), (0, 0), (1, 1)]
# Merging from index 3 to 6
# [(0, 3), (2, 4), (4, 5), (0, 2), (0, 0), (1, 1)]
# Merged section from index 3 to 6
# [(0, 3), (2, 4), (4, 5), (0, 0), (0, 2), (1, 1)]
# Merging from index 0 to 6
# [(0, 3), (2, 4), (4, 5), (0, 0), (0, 2), (1, 1)]
# Merged section from index 0 to 6
# [(0, 0), (0, 2), (0, 3), (1, 1), (2, 4), (4, 5)]
# Merge Sort - Comparisons: 10, Swaps: 16, Recursions: 11
# Merge sorted: [(0, 0), (0, 2), (0, 3), (1, 1), (2, 4), (4, 5)]
# ------ Sorting Example  18  ------------
# Original Data: [(2, 6), (4, 5), (2, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# golden_sorted_data [(0, 0), (0, 3), (1, 1), (2, 2), (2, 4), (2, 6), (4, 5)]
# Quick Sort: Sorting from index 0 to 6
# [(2, 6), (4, 5), (2, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Partitioned at index 5 with pivot (2, 6)
# [(1, 1), (0, 0), (2, 4), (0, 3), (2, 2), (2, 6), (4, 5)]
# Quick Sort: Sorting from index 0 to 4
# [(1, 1), (0, 0), (2, 4), (0, 3), (2, 2), (2, 6), (4, 5)]
# Partitioned at index 2 with pivot (1, 1)
# [(0, 3), (0, 0), (1, 1), (2, 4), (2, 2), (2, 6), (4, 5)]
# Quick Sort: Sorting from index 0 to 1
# [(0, 3), (0, 0), (1, 1), (2, 4), (2, 2), (2, 6), (4, 5)]
# Partitioned at index 1 with pivot (0, 3)
# [(0, 0), (0, 3), (1, 1), (2, 4), (2, 2), (2, 6), (4, 5)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 0), (0, 3), (1, 1), (2, 4), (2, 2), (2, 6), (4, 5)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 0), (0, 3), (1, 1), (2, 4), (2, 2), (2, 6), (4, 5)]
# Quick Sort: Sorting from index 3 to 4
# [(0, 0), (0, 3), (1, 1), (2, 4), (2, 2), (2, 6), (4, 5)]
# Partitioned at index 4 with pivot (2, 4)
# [(0, 0), (0, 3), (1, 1), (2, 2), (2, 4), (2, 6), (4, 5)]
# Quick Sort: Sorting from index 3 to 3
# [(0, 0), (0, 3), (1, 1), (2, 2), (2, 4), (2, 6), (4, 5)]
# Quick Sort: Sorting from index 5 to 4
# [(0, 0), (0, 3), (1, 1), (2, 2), (2, 4), (2, 6), (4, 5)]
# Quick Sort: Sorting from index 6 to 6
# [(0, 0), (0, 3), (1, 1), (2, 2), (2, 4), (2, 6), (4, 5)]
# Quick Sort - Comparisons: 12, Swaps: 6, Recursions: 9
# Quick sorted: [(0, 0), (0, 3), (1, 1), (2, 2), (2, 4), (2, 6), (4, 5)]
# Merge Sort: Sorting from index 0 to 7
# [(2, 6), (4, 5), (2, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 3
# [(2, 6), (4, 5), (2, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(2, 6), (4, 5), (2, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 3
# [(2, 6), (4, 5), (2, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 2
# [(2, 6), (4, 5), (2, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 3
# [(2, 6), (4, 5), (2, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merging from index 1 to 3
# [(2, 6), (4, 5), (2, 4), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merged section from index 1 to 3
# [(2, 6), (2, 4), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merging from index 0 to 3
# [(2, 6), (2, 4), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merged section from index 0 to 3
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 7
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 5
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 4
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 5
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merging from index 3 to 5
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merged section from index 3 to 5
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 5 to 7
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 5 to 6
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merge Sort: Sorting from index 6 to 7
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merging from index 5 to 7
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (1, 1), (0, 0)]
# Merged section from index 5 to 7
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (0, 0), (1, 1)]
# Merging from index 3 to 7
# [(2, 4), (2, 6), (4, 5), (0, 3), (2, 2), (0, 0), (1, 1)]
# Merged section from index 3 to 7
# [(2, 4), (2, 6), (4, 5), (0, 0), (0, 3), (1, 1), (2, 2)]
# Merging from index 0 to 7
# [(2, 4), (2, 6), (4, 5), (0, 0), (0, 3), (1, 1), (2, 2)]
# Merged section from index 0 to 7
# [(0, 0), (0, 3), (1, 1), (2, 2), (2, 4), (2, 6), (4, 5)]
# Merge Sort - Comparisons: 12, Swaps: 20, Recursions: 13
# Merge sorted: [(0, 0), (0, 3), (1, 1), (2, 2), (2, 4), (2, 6), (4, 5)]
# ------ Sorting Example  19  ------------
# Original Data: [(4, 7), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# golden_sorted_data [(0, 0), (0, 1), (0, 4), (2, 2), (2, 3), (2, 5), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 0 to 7
# [(4, 7), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Partitioned at index 7 with pivot (4, 7)
# [(0, 0), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (4, 7)]
# Quick Sort: Sorting from index 0 to 6
# [(0, 0), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (4, 7)]
# Partitioned at index 2 with pivot (0, 0)
# [(0, 4), (0, 1), (0, 0), (2, 5), (2, 3), (2, 2), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 0 to 1
# [(0, 4), (0, 1), (0, 0), (2, 5), (2, 3), (2, 2), (4, 6), (4, 7)]
# Partitioned at index 1 with pivot (0, 4)
# [(0, 1), (0, 4), (0, 0), (2, 5), (2, 3), (2, 2), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 4), (0, 0), (2, 5), (2, 3), (2, 2), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 2 to 1
# [(0, 1), (0, 4), (0, 0), (2, 5), (2, 3), (2, 2), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 3 to 6
# [(0, 1), (0, 4), (0, 0), (2, 5), (2, 3), (2, 2), (4, 6), (4, 7)]
# Partitioned at index 5 with pivot (2, 5)
# [(0, 1), (0, 4), (0, 0), (2, 2), (2, 3), (2, 5), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 3 to 4
# [(0, 1), (0, 4), (0, 0), (2, 2), (2, 3), (2, 5), (4, 6), (4, 7)]
# Partitioned at index 4 with pivot (2, 2)
# [(0, 1), (0, 4), (0, 0), (2, 3), (2, 2), (2, 5), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 3 to 3
# [(0, 1), (0, 4), (0, 0), (2, 3), (2, 2), (2, 5), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 5 to 4
# [(0, 1), (0, 4), (0, 0), (2, 3), (2, 2), (2, 5), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 6 to 6
# [(0, 1), (0, 4), (0, 0), (2, 3), (2, 2), (2, 5), (4, 6), (4, 7)]
# Quick Sort: Sorting from index 8 to 7
# [(0, 1), (0, 4), (0, 0), (2, 3), (2, 2), (2, 5), (4, 6), (4, 7)]
# Quick Sort - Comparisons: 18, Swaps: 7, Recursions: 11
# Quick sorted: [(0, 1), (0, 4), (0, 0), (2, 3), (2, 2), (2, 5), (4, 6), (4, 7)]
# Merge Sort: Sorting from index 0 to 8
# [(4, 7), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 4
# [(4, 7), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 2
# [(4, 7), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(4, 7), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 2
# [(4, 7), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merging from index 0 to 2
# [(4, 7), (4, 6), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merged section from index 0 to 2
# [(4, 6), (4, 7), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 4
# [(4, 6), (4, 7), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 3
# [(4, 6), (4, 7), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 4
# [(4, 6), (4, 7), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merging from index 2 to 4
# [(4, 6), (4, 7), (2, 5), (0, 4), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merged section from index 2 to 4
# [(4, 6), (4, 7), (0, 4), (2, 5), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merging from index 0 to 4
# [(4, 6), (4, 7), (0, 4), (2, 5), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merged section from index 0 to 4
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 8
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 6
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 5
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 5 to 6
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merging from index 4 to 6
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 3), (2, 2), (0, 1), (0, 0)]
# Merged section from index 4 to 6
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 2), (2, 3), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 6 to 8
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 2), (2, 3), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 6 to 7
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 2), (2, 3), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 7 to 8
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 2), (2, 3), (0, 1), (0, 0)]
# Merging from index 6 to 8
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 2), (2, 3), (0, 1), (0, 0)]
# Merged section from index 6 to 8
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 2), (2, 3), (0, 0), (0, 1)]
# Merging from index 4 to 8
# [(0, 4), (2, 5), (4, 6), (4, 7), (2, 2), (2, 3), (0, 0), (0, 1)]
# Merged section from index 4 to 8
# [(0, 4), (2, 5), (4, 6), (4, 7), (0, 0), (0, 1), (2, 2), (2, 3)]
# Merging from index 0 to 8
# [(0, 4), (2, 5), (4, 6), (4, 7), (0, 0), (0, 1), (2, 2), (2, 3)]
# Merged section from index 0 to 8
# [(0, 0), (0, 1), (0, 4), (2, 2), (2, 3), (2, 5), (4, 6), (4, 7)]
# Merge Sort - Comparisons: 13, Swaps: 24, Recursions: 15
# Merge sorted: [(0, 0), (0, 1), (0, 4), (2, 2), (2, 3), (2, 5), (4, 6), (4, 7)]
# ------ Sorting Example  20  ------------
# Original Data: [(6, 8), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# golden_sorted_data [(0, 0), (0, 1), (1, 2), (1, 4), (2, 7), (3, 3), (3, 5), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 0 to 8
# [(6, 8), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Partitioned at index 8 with pivot (6, 8)
# [(0, 0), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (6, 8)]
# Quick Sort: Sorting from index 0 to 7
# [(0, 0), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (6, 8)]
# Partitioned at index 1 with pivot (0, 0)
# [(0, 1), (0, 0), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (2, 7), (6, 8)]
# Quick Sort: Sorting from index 0 to 0
# [(0, 1), (0, 0), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (2, 7), (6, 8)]
# Quick Sort: Sorting from index 2 to 7
# [(0, 1), (0, 0), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (2, 7), (6, 8)]
# Partitioned at index 7 with pivot (6, 6)
# [(0, 1), (0, 0), (2, 7), (3, 5), (1, 4), (3, 3), (1, 2), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 2 to 6
# [(0, 1), (0, 0), (2, 7), (3, 5), (1, 4), (3, 3), (1, 2), (6, 6), (6, 8)]
# Partitioned at index 4 with pivot (2, 7)
# [(0, 1), (0, 0), (1, 4), (1, 2), (2, 7), (3, 3), (3, 5), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 2 to 3
# [(0, 1), (0, 0), (1, 4), (1, 2), (2, 7), (3, 3), (3, 5), (6, 6), (6, 8)]
# Partitioned at index 3 with pivot (1, 4)
# [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 3), (3, 5), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 2 to 2
# [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 3), (3, 5), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 4 to 3
# [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 3), (3, 5), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 5 to 6
# [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 3), (3, 5), (6, 6), (6, 8)]
# Partitioned at index 6 with pivot (3, 3)
# [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 5), (3, 3), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 5 to 5
# [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 5), (3, 3), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 7 to 6
# [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 5), (3, 3), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 8 to 7
# [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 5), (3, 3), (6, 6), (6, 8)]
# Quick Sort: Sorting from index 9 to 8
# [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 5), (3, 3), (6, 6), (6, 8)]
# Quick Sort - Comparisons: 26, Swaps: 8, Recursions: 13
# Quick sorted: [(0, 1), (0, 0), (1, 2), (1, 4), (2, 7), (3, 5), (3, 3), (6, 6), (6, 8)]
# Merge Sort: Sorting from index 0 to 9
# [(6, 8), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 4
# [(6, 8), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 2
# [(6, 8), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 0 to 1
# [(6, 8), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 1 to 2
# [(6, 8), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merging from index 0 to 2
# [(6, 8), (2, 7), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merged section from index 0 to 2
# [(2, 7), (6, 8), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 4
# [(2, 7), (6, 8), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 2 to 3
# [(2, 7), (6, 8), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 3 to 4
# [(2, 7), (6, 8), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merging from index 2 to 4
# [(2, 7), (6, 8), (6, 6), (3, 5), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merged section from index 2 to 4
# [(2, 7), (6, 8), (3, 5), (6, 6), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merging from index 0 to 4
# [(2, 7), (6, 8), (3, 5), (6, 6), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merged section from index 0 to 4
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 6
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 4 to 5
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 5 to 6
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merging from index 4 to 6
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merged section from index 4 to 6
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 6 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 6 to 7
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 7 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 7 to 8
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merge Sort: Sorting from index 8 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merging from index 7 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 1), (0, 0)]
# Merged section from index 7 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 0), (0, 1)]
# Merging from index 6 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (1, 2), (0, 0), (0, 1)]
# Merged section from index 6 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (0, 0), (0, 1), (1, 2)]
# Merging from index 4 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (1, 4), (3, 3), (0, 0), (0, 1), (1, 2)]
# Merged section from index 4 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (0, 0), (0, 1), (1, 2), (1, 4), (3, 3)]
# Merging from index 0 to 9
# [(2, 7), (3, 5), (6, 6), (6, 8), (0, 0), (0, 1), (1, 2), (1, 4), (3, 3)]
# Merged section from index 0 to 9
# [(0, 0), (0, 1), (1, 2), (1, 4), (2, 7), (3, 3), (3, 5), (6, 6), (6, 8)]
# Merge Sort - Comparisons: 18, Swaps: 29, Recursions: 17
# Merge sorted: [(0, 0), (0, 1), (1, 2), (1, 4), (2, 7), (3, 3), (3, 5), (6, 6), (6, 8)]
# Basic Sort test Passed.
